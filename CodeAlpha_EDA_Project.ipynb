# %% [markdown]
# # Global Layoffs Data Analysis (EDA Project)
#
# ## CodeAlpha Data Analytics Internship — Task 2
#
# ### Objective
# The objective of this project is to perform Exploratory Data Analysis (EDA) on a global layoffs dataset to identify trends, patterns, and business insights using Python. The dataset contains information about layoffs in various industries and countries.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("layoffs.csv")
df.head()
# Out:
#       company           location  total_laid_off       date  \
# 0     Pentera             Boston            40.0  4/27/2026
# 1    SuperOps  Chennai, Non-U.S.            60.0  4/24/2026
# 2        Acko   Mumbai, Non-U.S.            60.0  4/20/2026
# 3        Meta        SF Bay Area          8000.0  4/17/2026
# 4  Shutterfly    Haifa, Non-U.S.            80.0  4/16/2026
#
#    percentage_laid_off       industry  \
# 0                 0.08       Security
# 1                 0.30          Other
# 2                 0.05        Finance
# 3                 0.10       Consumer
# 4                  NaN  Manufacturing
#
#                                               source     stage  funds_raised  \
# 0  https://www.calcalistech.com/ctechnews/article...  Series D         249.0
# 1  https://inc42.com/buzz/superops-lays-off-30-st...  Series C          54.0
# 2  https://inc42.com/buzz/acko-cuts-5-workforce-i...   Unknown         143.0
# ...

# %%
df.shape
# Out:
# (4365, 11)

# %%
df.columns
# Out:
# Index(['company', 'location', 'total_laid_off', 'date', 'percentage_laid_off',
#        'industry', 'source', 'stage', 'funds_raised', 'country', 'date_added'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4365 entries, 0 to 4364
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              4365 non-null   object
#  1   location             4364 non-null   object
#  2   total_laid_off       2854 non-null   float64
#  3   date                 4364 non-null   object
#  4   percentage_laid_off  2745 non-null   float64
#  5   industry             4363 non-null   object
#  6   source               4362 non-null   object
#  7   stage                4360 non-null   object
#  8   funds_raised         3865 non-null   float64
#  9   country              4363 non-null   object
#  10  date_added           4365 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 375.2+ KB

# %%
df.isnull().sum()
# Out:
# company                   0
# location                  1
# total_laid_off         1511
# date                      1
# percentage_laid_off    1620
# industry                  2
# source                    3
# stage                     5
# funds_raised            500
# country                   2
# date_added                0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# company                0
# location               0
# total_laid_off         0
# date                   0
# percentage_laid_off    0
# industry               0
# source                 0
# stage                  0
# funds_raised           0
# country                0
# date_added             0
# dtype: int64

# %%
# Q1. which company has the highest number of layoffs?

top_company = df.groupby('company')['total_laid_off'].sum().sort_values(ascending=False).head(10)

print(top_company)
# Out:
# company
# Intel         37000.0
# Amazon        32000.0
# Microsoft     25305.0
# Meta          24100.0
# Tesla         14000.0
# Cisco         13950.0
# Google        12000.0
# Salesforce    11700.0
# SAP           11000.0
# Ericsson       8500.0
# Name: total_laid_off, dtype: float64

# %%
# visualization
top_company.plot(kind='bar', figsize=(10,5))
plt.title('Top 10 Companies with  Layoffs')
plt.xlabel('Company')
plt.ylabel('Employees Laid Off')

plt.show()

# %%
## Q2 which industry  affected most?

industry = df.groupby('industry')['total_laid_off'].sum().sort_values(ascending=False).head(10)
industry.plot(kind='bar',figsize=(10,5))

plt.title("Most Affected Industries")

plt.show()

# %%
## which country had most layoffs?

country = df.groupby('country')['total_laid_off'].sum().sort_values(ascending=False).head(10)
country.plot(kind='pie',autopct='%1.1f%%')
plt.title(" Layoffs by Country")
plt.ylabel("")
plt.show()

# %%
# time series analysis
df['date'] = pd.to_datetime(df['date'])

# %%
monthly = df.groupby(df['date'].dt.to_period('M'))['total_laid_off'].sum()

monthly.plot(figsize=(12,5))

plt.title("Monthly Layoff Trend")

plt.xlabel("Month")

plt.ylabel("Layoffs")

plt.show()

# %% [markdown]
# # Key Insights
#
# - Tech companies experienced the highest layoffs.
# - United States recorded maximum layoffs globally.
# - Layoffs increased significantly during recession periods.
# - Several funded startups also reduced workforce.

# %% [markdown]
# Project Summary / Conclusion
# Explanation
#
# Final findings aur learnings summarize ki jati hain.

# %% [markdown]
# # Project Summary
#
# This project focused on performing Exploratory Data Analysis (EDA) on a global layoffs dataset using Python.
#
# The dataset was cleaned and analyzed to identify trends, patterns, and business insights related to company layoffs across different industries and countries.
#
# Various visualizations such as bar charts, pie charts, and line graphs were created to better understand the data.
#
# This project helped improve practical skills in:
# - Data Cleaning
# - Data Analysis
# - Data Visualization
# - Python Programming
# - Business Insight Generation
